# %%
import numpy as np
import matplotlib.pyplot as plt
from mcmlpy import MCSub

# %config InlineBackend.figure_format='retina'

# %%
path = '../tests/'
filename = 'mcOUT1.dat'

s = MCSub()
s.init_from_file(path + filename)
print(s)
s.plot_reflectance()
s.plot_fluence()
# Out:
# photons       = 1000000
#
# R_unscattered =  0.04000
# R_scattered   =  0.00000
# R_total       =  0.04000
# T_unscattered =  0.00000
# T_scattered   =  0.00000
# T_total       =  0.00000
# Absorbed      =  0.96000
# Total         =  1.00000
#
# r_bins =   21, dr = 0.250 mm
# z_bins =  101, dz = 0.050 mm
#
# above:
#     n=1.000
# layer 1:
#     n=1.500 mu_a=5.00 mm⁻¹ mu_s=0.00 mm⁻¹ g=0.00 d=infinite
#
# flat top beam radius = 2 mm
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 8
#       6 print(s)
#       7 s.plot_reflectance()
# ----> 8 s.plot_fluence()
#
# File ~/Documents/Code/git/mcmlpy/mcmlpy/mcml.py:302, in MCML.plot_fluence(self, min_val)
#     299 zmax = np.max(logF)
#     300 masked = np.ma.masked_less(logF, zmin)
# --> 302 cmap = cm.get_cmap('gist_ncar')
#     303 cmap.set_bad(color='black')  # Set the color for masked values
# ...
