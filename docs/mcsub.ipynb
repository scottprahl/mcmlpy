# %% [markdown]
# # Simple parsing of mcsub output
#
# **Scott Prahl**
#
# **June 2024**

# %%
import numpy as np
import matplotlib.pyplot as plt
from mcmlpy import MCSub

# %config InlineBackend.figure_format='retina'

# %% [markdown]
# Read the output form mcsub and print a summary

# %%
filename = '../tests/mcOUT1.dat'

s = MCSub()
s.init_from_file(filename)
print(s)
# Out:
# photons       = 1000000
#
# R_unscattered =  0.04000
# R_scattered   =  0.00000
# R_total       =  0.04000
# T_unscattered =  0.00000
# T_scattered   =  0.00000
# T_total       =  0.00000
# Absorbed      =  0.96000
# Total         =  1.00000
#
# r_bins =   21, dr = 0.250 mm
# z_bins =  101, dz = 0.050 mm
#
# above:
#     n=1.000
# layer 1:
#     n=1.500 mu_a=5.00 mm⁻¹ mu_s=0.00 mm⁻¹ g=0.00 d=infinite
#
# flat top beam radius = 2 mm

# %%
s.plot_reflectance()
plt.show()

# %%
s.plot_fluence()
plt.show()
